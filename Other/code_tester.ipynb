# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
df = pd.read_csv('salary_survey_cleaned.csv')

# %%
rows, cols = df.shape
print("Rows:", rows, "Columns:", cols)

print("Missing values:")
print(df.isna().sum())
# Out:
# Rows: 28049 Columns: 9
# Missing values:
# age_range                     0
# industry                     83
# job_title                     4
# annual_salary                 0
# currency                      0
# country                       1
# current_years_experience      0
# education                   236
# gender                        0
# dtype: int64

# %%
df_usd = df[df['currency'] == 'USD'].copy()

# usd.value_counts()
# print(f"USD respondents: {len(usd):,} of {len(df):,} ({len(usd)/len(df):.0%})")

# %%
df_usd = df
